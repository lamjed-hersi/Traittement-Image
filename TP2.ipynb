# %% [markdown]
# <a href="https://colab.research.google.com/github/lamjed-hersi/Traittement-Image/blob/main/TP2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt 
import cv2 as cv

# %%
im1=plt.imread('/content/drive/MyDrive/images2021/lena.bmp')
m,n = im1.shape
imn=255-im1
plt.figure()
plt.imshow(imn,cmap='gray')
imv=im1[:,::-1]
imh=im1[::-1,:]
imc=im1[::-1,::-1]

# %%
plt.figure()
plt.subplot(221)
plt.imshow(im1,cmap='gray'), plt.title('img lena'), plt.xticks([]), plt.yticks([])
plt.subplot(222)
plt.imshow(imv,cmap='gray'), plt.title('sym V'), plt.xticks([]), plt.yticks([])
plt.subplot(223)
plt.imshow(imh,cmap='gray'), plt.title('sym H'), plt.xticks([]), plt.yticks([])
plt.subplot(224)
plt.imshow(imc,cmap='gray'), plt.title('sym C'), plt.xticks([]), plt.yticks([])
# Out:
# (<matplotlib.image.AxesImage at 0x7fb46ed00c90>,
#  Text(0.5, 1.0, 'sym C'),
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %%
a=plt.imread('/content/drive/MyDrive/images2021/rectangle.bmp')
a.shape
a = a[:,:,0]/255
b=plt.imread('/content/drive/MyDrive/images2021/cercle.bmp')
b = b[:,:,0]/255
c=plt.imread('/content/drive/MyDrive/images2021/triangle.bmp')
c = c[:,:,0]/255

# %%
#Visualisation
plt.close()
plt.figure()
plt.subplot(231)
plt.imshow(a,cmap='gray')
plt.xticks([]), plt.yticks([])
plt.subplot(232)
plt.imshow(b,cmap='gray')
plt.xticks([]), plt.yticks([])
plt.subplot(233)
plt.imshow(c,cmap='gray')
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %%
## OU AND NOT
im1 = np.logical_and(np.logical_and(a,b),c)*1
# ou bien d=d.asype(int)
im2 = np.logical_or(np.logical_or(a,b),c)*1
im3 = np.logical_not(np.logical_not(a,b),c)*1

# %%
plt.close()
plt.figure()
plt.subplot(231)
plt.imshow(im1,cmap='gray')
plt.xticks([]), plt.yticks([])
plt.subplot(232)
plt.imshow(im2,cmap='gray')
plt.xticks([]), plt.yticks([])
plt.subplot(233)
plt.imshow(im3,cmap='gray')
plt.xticks([]), plt.yticks([])
# Out:
# (([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %%
imcont=plt.imread('/content/drive/MyDrive/images2021/contour.bmp')
imcont=imcont[:,:,0]
imseq=plt.imread('/content/drive/MyDrive/images2021/seq1.bmp')
plt.figure()
plt.subplot(241)
plt.imshow(imcont,cmap='gray')
plt.subplot(242)
plt.imshow(imseq,cmap='gray')
incont=np.double(imcont)
imseq=np.double(imseq)
ims=np.minimum(imcont+imseq,255)
ims2=np.uint8(ims)
plt.subplot(243)
plt.imshow(ims2,cmap='gray')

# %%
imc1=plt.imread('/content/drive/MyDrive/images2021/carre1.png')
imc2=plt.imread('/content/drive/MyDrive/images2021/carre2.png')
f=np.fft.fft2(imc1)
sf=np.abs(f)
sfc1=np.fft.fftshift(sf)
sfc2=np.fft.fftshift(np.abs(np.fft.fft2(imc2)))

# visualisation

plt.figure()
plt.subplot(221),plt.imshow(imc1, cmap = 'gray')
plt.xticks([]), plt.yticks([])
plt.subplot(222),plt.imshow(imc2, cmap = 'gray')
plt.xticks([]), plt.yticks([])

plt.subplot(223),plt.imshow(sfc1, cmap='jet')
plt.title('Magnitude Spectrum carre1'), plt.xticks([]), plt.yticks([])
plt.subplot(224),plt.imshow(sfc2, cmap='jet')
plt.title('Magnitude Spectrum carre2'), plt.xticks([]), plt.yticks([])

fig=plt.figure()
xx1, yy1 = np.mgrid[0:sfc1.shape[0], 0:sfc1.shape[1]]
ax = fig.gca(projection='3d')
ax.plot_surface(xx1, yy1, sfc1, cmap='jet')

fig = plt.figure()
xx2, yy2 = np.mgrid[0:sfc2.shape[0], 0:sfc2.shape[1]]
ax = fig.gca(projection='3d')
ax.plot_surface(xx2, yy2, sfc2, cmap='jet')

# %%
imdec1=plt.imread('/content/drive/MyDrive/images2021/carre1.png')
imdec2=plt.imread('/content/drive/MyDrive/images2021/carre1dec1.png')
imdec3=plt.imread('/content/drive/MyDrive/images2021/carre1dec2.png')
imdec4=plt.imread('/content/drive/MyDrive/images2021/carre1dec3.png')
imdec5=plt.imread('/content/drive/MyDrive/images2021/carre1r45.png')
sfc3=np.fft.fftshift(np.abs(np.fft.fft2(imdec1)))
sfc4=np.fft.fftshift(np.abs(np.fft.fft2(imdec2)))
sfc5=np.fft.fftshift(np.abs(np.fft.fft2(imdec3)))
sfc6=np.fft.fftshift(np.abs(np.fft.fft2(imdec4)))
sfc7=np.fft.fftshift(np.abs(np.fft.fft2(imdec5)))

# %%
#Visualisation
plt.figure()
plt.subplot(251),plt.imshow(imdec1, cmap = 'gray'), plt.title('c1'), plt.xticks([]), plt.yticks([])
plt.subplot(252),plt.imshow(imdec2, cmap = 'gray'), plt.title('c1d1'), plt.xticks([]), plt.yticks([])
plt.subplot(253),plt.imshow(imdec3, cmap = 'gray'), plt.title('c1d2'), plt.xticks([]), plt.yticks([])
plt.subplot(254),plt.imshow(imdec4, cmap = 'gray'), plt.title('c1d3'), plt.xticks([]), plt.yticks([])
plt.subplot(255),plt.imshow(imdec5, cmap = 'gray'), plt.title('c1r45'), plt.xticks([]), plt.yticks([])

plt.subplot(256),plt.imshow(sfc3, cmap='jet'), plt.xticks([]), plt.yticks([])
plt.subplot(257),plt.imshow(sfc4, cmap='jet'), plt.xticks([]), plt.yticks([])
plt.subplot(258),plt.imshow(sfc5, cmap='jet'), plt.xticks([]), plt.yticks([])
plt.subplot(259),plt.imshow(sfc6, cmap='jet'), plt.xticks([]), plt.yticks([])
plt.subplot(2,5,10),plt.imshow(sfc7, cmap='jet'), plt.xticks([]), plt.yticks([])
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fb46b81f910>,
# ...
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))

# %%
imde1=plt.imread('/content/drive/MyDrive/images2021/sinus1.png')
imde2=plt.imread('/content/drive/MyDrive/images2021/sinus1r45.png')
imde3=plt.imread('/content/drive/MyDrive/images2021/sinus1r90.png')
sfc3=np.fft.fftshift(np.abs(np.fft.fft2(imde1)))
sfc4=np.fft.fftshift(np.abs(np.fft.fft2(imde2)))
sfc5=np.fft.fftshift(np.abs(np.fft.fft2(imde3)))

# %%
#Visualisation
plt.figure()
plt.subplot(253),plt.imshow(imde1, cmap = 'gray'), plt.title('c1d2'), plt.xticks([]), plt.yticks([])
plt.subplot(254),plt.imshow(imde2, cmap = 'gray'), plt.title('c1d3'), plt.xticks([]), plt.yticks([])
plt.subplot(255),plt.imshow(imde3, cmap = 'gray'), plt.title('c1r45'), plt.xticks([]), plt.yticks([])

plt.subplot(256),plt.imshow(sfc3, cmap='jet'), plt.xticks([]), plt.yticks([])
plt.subplot(257),plt.imshow(sfc4, cmap='jet'), plt.xticks([]), plt.yticks([])
plt.subplot(258),plt.imshow(sfc5, cmap='jet'), plt.xticks([]), plt.yticks([])
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x7fb46bb840d0>,
# ...
#  ([], <a list of 0 Text major ticklabel objects>),
#  ([], <a list of 0 Text major ticklabel objects>))
